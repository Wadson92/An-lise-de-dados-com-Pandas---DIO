# %%
print("Olá mundo!")
# Out:
# Olá mundo!

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
2 + 2
# Out:
# 4

# %%
2 ** 2
# Out:
# 4

# %%
#Esse é um comentário em python

# %%
num = 10
num / 2
# Out:
# 5.0

# %%
num // 2
# Out:
# 5
